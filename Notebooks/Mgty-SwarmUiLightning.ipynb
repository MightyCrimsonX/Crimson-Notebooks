# %% [markdown]
# # Notebook Swarmui Lightning por Mighty Crimson

# %% [markdown]
# ## <font color="Orange">Dependencias. Solo Usarlo una vez.</font>

# %%
from IPython.display import clear_output
from IPython.display import display, HTML
import os
# %cd -q /teamspace/studios/this_studio/
# !wget -q https://raw.githubusercontent.com/MightyCrimsonX/Notebook_Scripts/refs/heads/main/Swarmui_Lightning/install_swarmui_lightning.py
# %run install_swarmui_lightning.py
# %cd -q /teamspace/studios/this_studio/
# %run symb.py
clear_output()
display(HTML(f"<h1 style='color: yellow;'>Instalación completada</h1>"))

# %% [markdown]
# # <font color="purple">Activa esta celda para actualizar swarm, comfy y descargar archivos faltantes</font>

# %%
from IPython.display import clear_output
from IPython.display import display, HTML
import os
# %cd /teamspace/studios/this_studio/SwarmUI
# !git pull
# %cd /teamspace/studios/this_studio/SwarmUI/dlbackend/ComfyUI
# !git pull
# !uv pip install -r requirements.txt --no-progress
# %cd /teamspace/studios/this_studio/
if not os.path.exists("/teamspace/studios/this_studio/gestor_swarm.py"):
    # !wget -q https://huggingface.co/datasets/Mightys/Notebook_Scripts/resolve/main/Swarmui_Lightning/gestor_swarm.py -O /teamspace/studios/this_studio/gestor_swarm.py
if not os.path.exists("/teamspace/studios/this_studio/symb.py"):
    # !wget -q https://huggingface.co/datasets/Mightys/Notebook_Scripts/resolve/main/Swarmui_Lightning/symb.py -O /teamspace/studios/this_studio/symb.py
# !rm -rf /teamspace/studios/this_studio/.cache
clear_output()
display(HTML(f"<h1 style='color: yellow;'>Actualizacion Completada!</h1>"))

# %% [markdown]
# # <font color="blue">En este apartado se descargaran los modelos en carpetas temporales a excepcion de los Vae y Adetailers.</font>
# ## <font color="red"> Al inicial el studio, tienen que volver a descargar los modelos. Para descargar modelos de Civitai, tienen que editar la celda de abajo, donde dice `"TUTOKENCIVITAI"` (dentro de las comillas) cambian por el suyo.</font>
# ### **Ejecuten esta celda y reinicien el kernel cuando cambien su token de civitai**

# %%
# Celda: guardar token
import pickle, pathlib
token = "TUTOKENCIVITAI"
pathlib.Path.home().joinpath(".civitai_token.pkl").write_bytes(pickle.dumps(token))
print("✅ Token actualizado.")

# %% [markdown]
# # <font color="cyan">Mega Gestor de Modelos.</font>

# %%
import gestor_swarm
gestor_swarm.iniciar()

# %%
from IPython.display import clear_output
import os
import dmagic_swarm

# %run /teamspace/studios/this_studio/symb.py
clear_output()
os.chdir(TMP_MODELS)
# %download https://civitai.com/api/download/models/2673989?type=Model&format=SafeTensor&size=full&fp=fp16, https://civitai.com/api/download/models/2641077?type=Model&format=SafeTensor&size=full&fp=fp16, https://civitai.com/api/download/models/2578565?type=Model&format=SafeTensor&size=pruned&fp=fp16, https://civitai.com/api/download/models/1714002?type=Model&format=SafeTensor&size=pruned&fp=fp16
os.chdir(TMP_LORAS)
# %download

os.chdir(VAE_DIR)
# %download 

os.chdir(UPSCALER_DIR)
# %download https://huggingface.co/LyliaEngine/remacri_original/resolve/main/remacri_original.pt

os.chdir(TMP_CONTROLNET)
# %download https://huggingface.co/xinsir/controlnet-union-sdxl-1.0/resolve/main/diffusion_pytorch_model_promax.safetensors -o controlnet-union-ProMax.safetensors

os.chdir(TMP_DIFFUSION)
# %download

os.chdir(TMP_TEXT_ENCODERS)
# %download 

os.chdir(TMP_TIPOMODEL)
# %download https://huggingface.co/KBlueLeaf/TIPO-500M-ft/resolve/main/TIPO-500M-ft-F16.gguf

# %% [markdown]
# ## <font color="orange">Adetailer Models</font>

# %%
from IPython.display import clear_output
from IPython.display import display, HTML
import download_magic
# !mkdir -p /teamspace/studios/this_studio/SwarmUI/Models/yolov8
# %cd /teamspace/studios/this_studio/SwarmUI/Models/yolov8
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M "https://huggingface.co/Anzhc/Anzhcs_YOLOs/resolve/main/Anzhc%20Eyes%20-seg-hd.pt" -o Anzhc_Eyes-seg-hd.pt
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M "https://huggingface.co/Anzhc/Anzhcs_YOLOs/resolve/main/Anzhc%20Face%20seg%20640%20v3%20y11n.pt" -o Anzhc_Face_seg_v3_y11n.pt
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M "https://huggingface.co/Anzhc/Anzhcs_YOLOs/resolve/main/Anzhc%20Breasts%20Seg%20v1%201024n.pt" -o Anzhc_Breasts_Seg_v1_1024n.pt
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M "https://huggingface.co/Anzhc/Anzhcs_YOLOs/resolve/main/Anzhc%20HeadHair%20seg%20y8n.pt" -o Anzhc_HeadHair_seg_y8n.pt
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M "https://huggingface.co/Nudimmud/adetailers/resolve/main/assdetailer-seg.pt" -o assdetailer.pt
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M "https://huggingface.co/Bingsu/adetailer/resolve/main/face_yolov8n.pt" -o face_yolov8n.pt
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M "https://huggingface.co/Bingsu/adetailer/resolve/main/face_yolov8m.pt" -o face_yolov8m.pt
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M "https://huggingface.co/Bingsu/adetailer/resolve/main/hand_yolov8n.pt" -o hand_yolov8n.pt
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M "https://huggingface.co/Bingsu/adetailer/resolve/main/hand_yolov8m.pt" -o hand_yolov8m.pt

clear_output()
display(HTML(f"<h1 style='color: yellow;'>Adetailer Models Descargados</h1>"))

# %% [markdown]
# ## <font color="red">Usa esta celda si te aparece mucho almacenamiento</font>

# %%
# !rm -rf /teamspace/studios/this_studio/.cache

# %% [markdown]
# # Iniciar Swarmui
# El puerto es: 7801

# %%
#Si quieres usar SageAttention, en la config del arg del backend, agrega: --use-sage-attention
# %cd /teamspace/studios/this_studio/SwarmUI
# !LD_PRELOAD=/teamspace/studios/this_studio/libmimalloc.so.2.1  ./launch-linux.sh --launch_mode none --host 0.0.0.0 --port 7801

# %% [markdown]
# # 📦 Descarga imágenes generadas en zip (Output)

# %%
import shutil
folder_path = "/teamspace/studios/this_studio/SwarmUI/Output"
zip_path = "/teamspace/studios/this_studio/SwarmUI_Output.zip"
shutil.make_archive(zip_path.replace(".zip", ""), 'zip', folder_path)
