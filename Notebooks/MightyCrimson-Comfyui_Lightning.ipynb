# %% [markdown]
# # Notebook Comfyui Lightning por Mighty Crimson

# %% [markdown]
# ## <font color="Orange">Dependencias. Solo Usarlo una vez.</font>

# %%
from IPython.display import clear_output
from IPython.display import display, HTML
# !wget -q https://raw.githubusercontent.com/MightyCrimsonX/Notebook_Scripts/refs/heads/main/Comfyui-Lightning/Install_comfyui_lightning.py
# %run Install_comfyui_lightning.py
# %cd /teamspace/studios/this_studio
# %run temp_dir.py
clear_output()
display(HTML(f"<h1 style='color: yellow;'>Instalación completada</h1>"))

# %% [markdown]
# # <font color="green">En este apartado se descargaran los modelos en carpetas temporales a excepcion de los Vae y Adetailers.</font>
# ## <font color="red"> Al inicial el studio, tienen que volver a descargar los modelos. Para descargar modelos de Civitai, tienen que editar la celda de abajo, donde dice `"TUTOKENCIVITAI"`  cambian por el suyo, EL Token debe de estar dentro de las comillas.</font>
# ### **Ejecuten esta celda y reinicien el kernel cuando cambien su token de civitai**

# %%
import pickle, pathlib
token = "TUTOKENCIVITAI"
pathlib.Path.home().joinpath(".civitai_token.pkl").write_bytes(pickle.dumps(token))
print("✅ Token actualizado.")

# %% [markdown]
# # Mega Gestor de Descargas

# %%
import gestor_comfy
gestor_comfy.iniciar()

# %% [markdown]
# ### Descarga Clasica de Modelos (⏱️Temporales)
# Puedes separar los links con `,`

# %%
from IPython.display import clear_output
import os
import download_magic
# %run /teamspace/studios/this_studio/temp_dir.py
clear_output()
os.chdir(TMP_MODELS)
# %download 
os.chdir(TMP_LORAS)
# %download

os.chdir(VAE_DIR)
# %download 

os.chdir(UPSCALER_DIR)
# %download 

os.chdir(TMP_CONTROLNET)
# %download 

os.chdir(TMP_DIFFUSION)
# %download

os.chdir(TMP_TEXT_ENCODERS)
# %download 

os.chdir(TMP_TIPOMODEL)
# %download https://huggingface.co/KBlueLeaf/TIPO-500M-ft/resolve/main/TIPO-500M-ft-F16.gguf

# %% [markdown]
# ## <font color="red">Usa esta celda si te aparece mucho almacenamiento para eliminar el caché</font>

# %%
# !rm -rf /teamspace/studios/this_studio/.cache

# %% [markdown]
# # Iniciar Comfyui
# ### **Args Recomendados**
#  `--use-pytorch-attention`<br>
# `--use-sage-attention` (Solo usar si usas la T4 como GPU. Inestable en la T4, use con precaución)<br>
# `--fast fp16_accumulation`

# %%
# %cd /teamspace/studios/this_studio/ComfyUI
# !LD_PRELOAD=/teamspace/studios/this_studio/libmimalloc.so.2.1 python main.py --highvram  --preview-method latent2rgb

# %% [markdown]
# # 📦 Descarga imágenes generadas en zip (Output)

# %%
import shutil
folder_path = "/teamspace/studios/this_studio/ComfyUI/output"
zip_path = "/teamspace/studios/this_studio/ComfyUI_Output.zip"
shutil.make_archive(zip_path.replace(".zip", ""), 'zip', folder_path)

# %% [markdown]
# ## 🗑️ Eliminar Carpeta Outputs (ELIMINARÁ TODAS LAS IMAGENES GENERADAS!

# %%
# !rm -rf /teamspace/studios/this_studio/ComfyUI/output

# %% [markdown]
# ## <font color="orange">Adetailer Models</font>

# %%
#@markdown # **Descargar Modelos Segmentation/Adetailer**
from IPython.display import clear_output
from IPython.display import display, HTML

# !mkdir -p /teamspace/studios/this_studio/ComfyUI/models/ultralytics/segm
# %cd /teamspace/studios/this_studio/ComfyUI/models/ultralytics/segm

# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M "https://huggingface.co/Anzhc/Anzhcs_YOLOs/resolve/main/Anzhc%20Eyes%20-seg-hd.pt" -o Anzhc_Eyes-seg-hd.pt
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M "https://huggingface.co/Anzhc/Anzhcs_YOLOs/resolve/main/Anzhc%20Face%20seg%20640%20v3%20y11n.pt" -o Anzhc_Face_seg_v3_y11n.pt
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M "https://huggingface.co/Anzhc/Anzhcs_YOLOs/resolve/main/Anzhc%20Breasts%20Seg%20v1%201024n.pt" -o Anzhc_Breasts_Seg_v1_1024n.pt
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M "https://huggingface.co/Anzhc/Anzhcs_YOLOs/resolve/main/Anzhc%20HeadHair%20seg%20y8n.pt" -o Anzhc_HeadHair_seg_y8n.pt
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M "https://huggingface.co/Nudimmud/adetailers/resolve/main/assdetailer-seg.pt" -o assdetailer.pt

# !mkdir -p /teamspace/studios/this_studio/ComfyUI/models/ultralytics/bbox
# %cd /teamspace/studios/this_studio/ComfyUI/models/ultralytics/bbox
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M "https://huggingface.co/Bingsu/adetailer/resolve/main/face_yolov8n.pt" -o face_yolov8n.pt
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M "https://huggingface.co/Bingsu/adetailer/resolve/main/face_yolov8m.pt" -o face_yolov8m.pt
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M "https://huggingface.co/Bingsu/adetailer/resolve/main/hand_yolov8n.pt" -o hand_yolov8n.pt
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M "https://huggingface.co/Bingsu/adetailer/resolve/main/hand_yolov8m.pt" -o hand_yolov8m.pt
clear_output()
display(HTML(f"<h1 style='color: yellow;'>Descarga Finalizada</h1>"))
